# %% [markdown]
# <a href="https://colab.research.google.com/github/yoonhamin/2026-1_CV/blob/main/01%EC%A3%BC/1%2B1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
r = 1 + 1
print(r)
# Out:
# 2
